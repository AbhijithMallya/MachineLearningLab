# %%
import pandas as pd

# Load the dataset from CSV
dataset = pd.read_csv('dataset.csv')

print("Original dataset:")
print(dataset.head(10)) #10 means to show 1st ten records

#Delete rows that contain duplicate data
dataset_duplicates_removed = dataset.drop_duplicates()
print("\nDataset with duplicate rows removed:")
print(dataset_duplicates_removed.head(10))

#Delete columns that contain a single value
dataset_columns_removed = dataset_duplicates_removed.loc[:, dataset_duplicates_removed.nunique() > 1]
print("\nDataset with columns containing a single value removed:")
print(dataset_columns_removed.head(10))
# Out:
# Original dataset:
#    Col1 Col2  Col3 Col4
# 0     1    A     1    D
# 1     2    B     2    D
# 2     3    C     3    D
# 3     4    D     4    D
# 4     4    D     4    D
# 5     5    E     5    D
# 6     6    F     6    D
# 7     7    G     7    D
# 8     7    G     7    D
# 9     8    H     8    D
#
# Dataset with duplicate rows removed:
#     Col1 Col2  Col3 Col4
# 0      1    A     1    D
# 1      2    B     2    D
# 2      3    C     3    D
# 3      4    D     4    D
# 5      5    E     5    D
# 6      6    F     6    D
# 7      7    G     7    D
# 9      8    H     8    D
# 10     9    I     9    D
# 11    10    J    10    D
#
# Dataset with columns containing a single value removed:
#     Col1 Col2  Col3
# 0      1    A     1
# 1      2    B     2
# 2      3    C     3
# 3      4    D     4
# 5      5    E     5
# 6      6    F     6
# 7      7    G     7
# 9      8    H     8
# 10     9    I     9
# 11    10    J    10
