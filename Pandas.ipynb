# %% [markdown]
# ### PANDAS

# %% [markdown]
# ### Importing Pandas library

# %%
def pname():
    print("4SF20CI002 : ABHIJITH MALLYA")

# %%
import pandas as pd

# %% [markdown]
# ### Creating a Pandas Series

# %%
pname()
series = pd.Series([1,2,3,4,5])
series
# Out:
# 4SF20CI002 : ABHIJITH MALLYA
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %% [markdown]
# ### Creating a Pandas DataFrame

# %%
pname()
data = {'Name': ['John', 'Emily', 'Michael'],
        'Age': [25, 30, 35],
        'City': ['New York', 'Los Angeles', 'Chicago']}
df = pd.DataFrame(data)
print("Data Frame created successfully !")
# Out:
# 4SF20CI002 : ABHIJITH MALLYA
# Data Frame created successfully !

# %% [markdown]
# ### Viewing the first few rows of a DataFrame

# %%
pname()
df.head()
# Out:
# 4SF20CI002 : ABHIJITH MALLYA
#       Name  Age         City
# 0     John   25     New York
# 1    Emily   30  Los Angeles
# 2  Michael   35      Chicago

# %% [markdown]
# ### Accessing a column in a DataFrame

# %%
pname()
df['City']
# Out:
# 4SF20CI002 : ABHIJITH MALLYA
# 0       New York
# 1    Los Angeles
# 2        Chicago
# Name: City, dtype: object

# %% [markdown]
# ### Filtering Rows based  on a condition

# %%
pname()
filtered_df = df[df['Age'] > 30]
filtered_df
# Out:
# 4SF20CI002 : ABHIJITH MALLYA
#       Name  Age     City
# 2  Michael   35  Chicago

# %% [markdown]
# ### Sorting a DataFrame by a Column

# %%
pname()
sorted_df = df.sort_values('Age')
sorted_df
# Out:
# 4SF20CI002 : ABHIJITH MALLYA
#       Name  Age         City
# 0     John   25     New York
# 1    Emily   30  Los Angeles
# 2  Michael   35      Chicago

# %% [markdown]
# ### Performing statistical calculations in a Column

# %%
pname()
average_age = df['Age'].mean()
print("Average age :"+str(average_age))
# Out:
# 4SF20CI002 : ABHIJITH MALLYA
# Average age :30.0

# %% [markdown]
# ### Adding a new Column to a DataFrame

# %%
pname()
df['Gender'] = ['Male', 'Female', 'Male']
# Out:
# 4SF20CI002 : ABHIJITH MALLYA

# %% [markdown]
# ### Grouping and agregating data in a DataFrame

# %%
pname()
grouped_df = df.groupby('Gender').mean()
grouped_df
# Out:
# 4SF20CI002 : ABHIJITH MALLYA
# C:\Users\ABHIJITH_MALLYA\AppData\Local\Temp\ipykernel_13152\3191940500.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   grouped_df = df.groupby('Gender').mean()
#          Age
# Gender
# Female  30.0
# Male    30.0
