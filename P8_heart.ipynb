# %%
import numpy as np
import pandas as pd
import csv 
from pgmpy.estimators import MaximumLikelihoodEstimator
from pgmpy.models import BayesianModel
from pgmpy.inference import VariableElimination
heartDisease = pd.read_csv('P8_heart.csv')
heartDisease = heartDisease.replace('?',np.nan)
model= BayesianModel([('age','heartdisease'),('sex','heartdisease'),('exang','heartdisease'),('cp','heartdisease'),('heartdisease','restecg'),('heartdisease','chol')])
print('\nLearning CPD using Maximum likelihood estimators')
model.fit(heartDisease,estimator=MaximumLikelihoodEstimator)
print('\n Inferencing with Bayesian Network:')
HeartDiseasetest_infer = VariableElimination(model)
print('\n 1. Probability of HeartDisease given evidence= restecg')
q1=HeartDiseasetest_infer.query(variables=['heartdisease'],evidence={'restecg':1})
print(q1)
print('\n 2. Probability of HeartDisease given evidence= cp ')
q2=HeartDiseasetest_infer.query(variables=['heartdisease'],evidence={'cp':2})
print(q2)
# Out:
# Learning CPD using Maximum likelihood estimators
#
#  Inferencing with Bayesian Network:
# c:\Users\ABHIJITH_MALLYA\anaconda3\envs\hands_on_ML\lib\site-packages\pgmpy\models\BayesianModel.py:8: FutureWarning: BayesianModel has been renamed to BayesianNetwork. Please use BayesianNetwork class, BayesianModel will be removed in future.
#   warnings.warn(
# c:\Users\ABHIJITH_MALLYA\anaconda3\envs\hands_on_ML\lib\site-packages\pgmpy\factors\discrete\CPD.py:331: RuntimeWarning: invalid value encountered in divide
#   tabular_cpd.values = (cpd / cpd.sum(axis=0)).reshape(tabular_cpd.cardinality)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 13
#      11 model.fit(heartDisease,estimator=MaximumLikelihoodEstimator)
#      12 print('\n Inferencing with Bayesian Network:')
# ---> 13 HeartDiseasetest_infer = VariableElimination(model)
#      14 print('\n 1. Probability of HeartDisease given evidence= restecg')
#      15 q1=HeartDiseasetest_infer.query(variables=['heartdisease'],evidence={'restecg':1})
#
# File c:\Users\ABHIJITH_MALLYA\anaconda3\envs\hands_on_ML\lib\site-packages\pgmpy\inference\base.py:67, in Inference.__init__(self, model)
#      65 def __init__(self, model):
#      66     self.model = model
# ---> 67     model.check_model()
#      69     if isinstance(self.model, JunctionTree):
#      70         self.variables = set(chain(*self.model.nodes()))
#
# File c:\Users\ABHIJITH_MALLYA\anaconda3\envs\hands_on_ML\lib\site-packages\pgmpy\models\BayesianNetwork.py:423, in BayesianNetwork.check_model(self)
#     421 # Check if the values of the CPD sum to 1.
#     422 if not cpd.is_valid_cpd():
# --> 423     raise ValueError(
#     424         f"Sum or integral of conditional probabilities for node {node} is not equal to 1."
#     425     )
#     427 if len(set(cpd.variables) - set(cpd.state_names.keys())) > 0:
#     428     raise ValueError(
#     429         f"CPD for {node} doesn't have state names defined for all the variables."
#     430     )
#
# ValueError: Sum or integral of conditional probabilities for node heartdisease is not equal to 1.

# %%
import numpy as np
# from urllib.request import urlopen
# import urllib
import pandas as pd
from pgmpy.inference import VariableElimination
from pgmpy.models import BayesianModel 
from pgmpy.estimators import MaximumLikelihoodEstimator, BayesianEstimator
names = ['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach', 'exang', 'oldpeak', 'slope', 'ca', 'thal', 'heartdisease'] 
heartDisease = pd.read_csv('P8_heart.csv', names = names)
heartDisease = heartDisease.replace('?', np.nan) 
model = BayesianModel([('age', 'trestbps'), ('age', 'fbs'), ('sex', 'trestbps'), ('exang','trestbps'),('trestbps','heartdisease'),('fbs','heartdisease'),('heartdisease','restecg'), ('heartdisease','thalach'), ('heartdisease','chol')])
model.fit(heartDisease, estimator=MaximumLikelihoodEstimator)
HeartDisease_infer = VariableElimination(model)
q = HeartDisease_infer.query(variables=['heartdisease'], evidence={'age': 37, 'sex' :0})
print(q['heartdisease'])
# Out:
# c:\Users\ABHIJITH_MALLYA\anaconda3\envs\hands_on_ML\lib\site-packages\pgmpy\models\BayesianModel.py:8: FutureWarning: BayesianModel has been renamed to BayesianNetwork. Please use BayesianNetwork class, BayesianModel will be removed in future.
#   warnings.warn(
# c:\Users\ABHIJITH_MALLYA\anaconda3\envs\hands_on_ML\lib\site-packages\pgmpy\factors\discrete\CPD.py:331: RuntimeWarning: invalid value encountered in divide
#   tabular_cpd.values = (cpd / cpd.sum(axis=0)).reshape(tabular_cpd.cardinality)
# c:\Users\ABHIJITH_MALLYA\anaconda3\envs\hands_on_ML\lib\site-packages\pgmpy\factors\discrete\CPD.py:331: RuntimeWarning: invalid value encountered in divide
#   tabular_cpd.values = (cpd / cpd.sum(axis=0)).reshape(tabular_cpd.cardinality)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 13
#      11 model = BayesianModel([('age', 'trestbps'), ('age', 'fbs'), ('sex', 'trestbps'), ('exang','trestbps'),('trestbps','heartdisease'),('fbs','heartdisease'),('heartdisease','restecg'), ('heartdisease','thalach'), ('heartdisease','chol')])
#      12 model.fit(heartDisease, estimator=MaximumLikelihoodEstimator)
# ---> 13 HeartDisease_infer = VariableElimination(model)
#      14 q = HeartDisease_infer.query(variables=['heartdisease'], evidence={'age': 37, 'sex' :0})
#      15 print(q['heartdisease'])
#
# File c:\Users\ABHIJITH_MALLYA\anaconda3\envs\hands_on_ML\lib\site-packages\pgmpy\inference\base.py:67, in Inference.__init__(self, model)
#      65 def __init__(self, model):
#      66     self.model = model
# ---> 67     model.check_model()
#      69     if isinstance(self.model, JunctionTree):
#      70         self.variables = set(chain(*self.model.nodes()))
#
# File c:\Users\ABHIJITH_MALLYA\anaconda3\envs\hands_on_ML\lib\site-packages\pgmpy\models\BayesianNetwork.py:423, in BayesianNetwork.check_model(self)
#     421 # Check if the values of the CPD sum to 1.
#     422 if not cpd.is_valid_cpd():
# --> 423     raise ValueError(
#     424         f"Sum or integral of conditional probabilities for node {node} is not equal to 1."
#     425     )
#     427 if len(set(cpd.variables) - set(cpd.state_names.keys())) > 0:
#     428     raise ValueError(
#     429         f"CPD for {node} doesn't have state names defined for all the variables."
#     430     )
#
# ValueError: Sum or integral of conditional probabilities for node trestbps is not equal to 1.

# %%
import pandas as pd
from pgmpy.estimators import MaximumLikelihoodEstimator
from pgmpy.models import BayesianModel
from pgmpy.inference import VariableElimination

heartDisease = pd.read_csv('P8_heart.csv')
heartDisease = heartDisease.replace('?', np.nan)

model = BayesianModel([
    ('age', 'heartdisease'),
    ('sex', 'heartdisease'),
    ('exang', 'heartdisease'),
    ('cp', 'heartdisease'),
    ('restecg', 'heartdisease'),
    ('chol', 'heartdisease')
])

print('\nLearning CPD using Maximum likelihood estimators')
model.fit(heartDisease, estimator=MaximumLikelihoodEstimator)

print('\n Inferencing with Bayesian Network:')
HeartDiseasetest_infer = VariableElimination(model)

print('\n 1. Probability of HeartDisease given evidence= restecg')
q1 = HeartDiseasetest_infer.query(variables=['heartdisease'], evidence={'restecg': 1})
print(q1)

print('\n 2. Probability of HeartDisease given evidence= cp')
q2 = HeartDiseasetest_infer.query(variables=['heartdisease'], evidence={'cp': 2})
print(q2)
# Out:
# Learning CPD using Maximum likelihood estimators
#
#  Inferencing with Bayesian Network:
# c:\Users\ABHIJITH_MALLYA\anaconda3\envs\hands_on_ML\lib\site-packages\pgmpy\models\BayesianModel.py:8: FutureWarning: BayesianModel has been renamed to BayesianNetwork. Please use BayesianNetwork class, BayesianModel will be removed in future.
#   warnings.warn(
# c:\Users\ABHIJITH_MALLYA\anaconda3\envs\hands_on_ML\lib\site-packages\pgmpy\factors\discrete\CPD.py:331: RuntimeWarning: invalid value encountered in divide
#   tabular_cpd.values = (cpd / cpd.sum(axis=0)).reshape(tabular_cpd.cardinality)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 22
#      19 model.fit(heartDisease, estimator=MaximumLikelihoodEstimator)
#      21 print('\n Inferencing with Bayesian Network:')
# ---> 22 HeartDiseasetest_infer = VariableElimination(model)
#      24 print('\n 1. Probability of HeartDisease given evidence= restecg')
#      25 q1 = HeartDiseasetest_infer.query(variables=['heartdisease'], evidence={'restecg': 1})
#
# File c:\Users\ABHIJITH_MALLYA\anaconda3\envs\hands_on_ML\lib\site-packages\pgmpy\inference\base.py:67, in Inference.__init__(self, model)
#      65 def __init__(self, model):
#      66     self.model = model
# ---> 67     model.check_model()
#      69     if isinstance(self.model, JunctionTree):
#      70         self.variables = set(chain(*self.model.nodes()))
#
# File c:\Users\ABHIJITH_MALLYA\anaconda3\envs\hands_on_ML\lib\site-packages\pgmpy\models\BayesianNetwork.py:423, in BayesianNetwork.check_model(self)
#     421 # Check if the values of the CPD sum to 1.
#     422 if not cpd.is_valid_cpd():
# --> 423     raise ValueError(
#     424         f"Sum or integral of conditional probabilities for node {node} is not equal to 1."
#     425     )
#     427 if len(set(cpd.variables) - set(cpd.state_names.keys())) > 0:
#     428     raise ValueError(
#     429         f"CPD for {node} doesn't have state names defined for all the variables."
#     430     )
#
# ValueError: Sum or integral of conditional probabilities for node heartdisease is not equal to 1.
